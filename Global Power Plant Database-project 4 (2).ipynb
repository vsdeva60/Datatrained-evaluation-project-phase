# %% [markdown]
# # Global Power Plant Database

# %% [markdown]
# Description
#
# The Global Power Plant Database is a comprehensive, open source database of power plants around the world. It centralizes power plant data to make it easier to navigate, compare and draw insights for one’s own analysis. The database covers approximately 35,000 power plants from 167 countries and includes thermal plants (e.g. coal, gas, oil, nuclear, biomass, waste, geothermal) and renewables (e.g. hydro, wind, solar). Each power plant is geolocated and entries contain information on plant capacity, generation, ownership, and fuel type. It will be continuously updated as data becomes available.

# %% [raw]
# Fuel Type Aggregation
# We define the "Fuel Type" attribute of our database based on common fuel categories.
#
# Prediction :   Make two prediction  1) Primary Fuel    2) capacity_mw

# %%
# Importing some neccessary liabraries which will help us to understand and visualize data

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'E:\Data Science Certificates\Evaluation project\Global Power Plant Database\database_IND.csv')
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# 1           98.0   24.7663    74.6090         Coal         NaN         NaN
# 2           39.2   21.9038    69.3732         Wind         NaN         NaN
# 3          135.0   23.8712    91.3602          Gas         NaN         NaN
# 4         1800.0   21.9603    82.4091         Coal         Oil         NaN
# ..           ...       ...        ...          ...         ...         ...
# 902       1600.0   16.2949    77.3568         Coal         Oil         NaN
# 903          3.0   12.8932    78.1654        Solar         NaN         NaN
# 904         25.5   15.2758    75.5811         Wind         NaN         NaN
# 905         80.0   24.3500    73.7477         Coal         NaN         NaN
# 906         16.5    9.9344    77.4768         Wind         NaN         NaN
#
#      ...  year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 0    ...                    NaN                  NaN                 NaN
# 1    ...                    NaN                  NaN                 NaN
# 2    ...                    NaN                  NaN                 NaN
# 3    ...                 2019.0                  NaN          617.789264
# 4    ...                 2019.0                  NaN         3035.550000
# ..   ...                    ...                  ...                 ...
# 902  ...                 2019.0                  NaN                 NaN
# 903  ...                    NaN                  NaN                 NaN
# 904  ...                    NaN                  NaN                 NaN
# 905  ...                    NaN                  NaN                 NaN
# 906  ...                    NaN                  NaN                 NaN
#
#     generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 0                   NaN                 NaN                 NaN
# 1                   NaN                 NaN                 NaN
# 2                   NaN                 NaN                 NaN
# 3            843.747000          886.004428          663.774500
# 4           5916.370000         6243.000000         5385.579736
# ..                  ...                 ...                 ...
# 902            0.994875          233.596650          865.400000
# 903                 NaN                 NaN                 NaN
# 904                 NaN                 NaN                 NaN
# 905                 NaN                 NaN                 NaN
# 906                 NaN                 NaN                 NaN
#
#      generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 0                    NaN                  NaN                            NaN
# 1                    NaN                  NaN                            NaN
# 2                    NaN                  NaN                            NaN
# 3             626.239128                  NaN  Central Electricity Authority
# 4            7279.000000                  NaN  Central Electricity Authority
# ..                   ...                  ...                            ...
# 902           686.500000                  NaN  Central Electricity Authority
# 903                  NaN                  NaN                            NaN
# 904                  NaN                  NaN                            NaN
# 905                  NaN                  NaN                            NaN
# 906                  NaN                  NaN                            NaN
#
#      estimated_generation_gwh
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 902                       NaN
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
#
# [907 rows x 27 columns]

# %%
df.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 0                    NaN                  NaN                 NaN
# 1                    NaN                  NaN                 NaN
# 2                    NaN                  NaN                 NaN
# 3                 2019.0                  NaN          617.789264
# 4                 2019.0                  NaN         3035.550000
#
#   generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3             843.747          886.004428          663.774500
# 4            5916.370         6243.000000         5385.579736
#
#    generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 0                  NaN                  NaN                            NaN
# 1                  NaN                  NaN                            NaN
# 2                  NaN                  NaN                            NaN
# 3           626.239128                  NaN  Central Electricity Authority
# 4          7279.000000                  NaN  Central Electricity Authority
#
#    estimated_generation_gwh
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 27 columns]

# %%
df.tail()
# Out:
#     country country_long                          name   gppd_idnr  \
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 902       1600.0   16.2949    77.3568         Coal         Oil         NaN
# 903          3.0   12.8932    78.1654        Solar         NaN         NaN
# 904         25.5   15.2758    75.5811         Wind         NaN         NaN
# 905         80.0   24.3500    73.7477         Coal         NaN         NaN
# 906         16.5    9.9344    77.4768         Wind         NaN         NaN
#
#      ...  year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 902  ...                 2019.0                  NaN                 NaN
# 903  ...                    NaN                  NaN                 NaN
# 904  ...                    NaN                  NaN                 NaN
# 905  ...                    NaN                  NaN                 NaN
# 906  ...                    NaN                  NaN                 NaN
#
#     generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 902            0.994875           233.59665               865.4
# 903                 NaN                 NaN                 NaN
# 904                 NaN                 NaN                 NaN
# 905                 NaN                 NaN                 NaN
# 906                 NaN                 NaN                 NaN
#
#      generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 902                686.5                  NaN  Central Electricity Authority
# 903                  NaN                  NaN                            NaN
# 904                  NaN                  NaN                            NaN
# 905                  NaN                  NaN                            NaN
# 906                  NaN                  NaN                            NaN
#
#      estimated_generation_gwh
# 902                       NaN
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# Trying to see basic information of data and understading pattern

# %%
df.sample(5)
# Out:
#     country country_long                     name   gppd_idnr  capacity_mw  \
# 425     IND        India                LODHIVALI  WRI1019964         40.0
# 381     IND        India               KUTCH LIG.  IND0000222        290.0
# 757     IND        India         Satara Wind Farm  WRI1026076        100.0
# 597     IND        India      PRYAGRAJ (BARA) TPP  IND0000346       1980.0
# 190     IND        India  Dadri Solar Power Plant  WRI1026131          5.0
#
#      latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 425   18.9002    73.2032          Oil         NaN         NaN  ...
# 381   23.6626    68.7843         Coal         Oil         NaN  ...
# 757   17.2387    73.9096         Wind         NaN         NaN  ...
# 597   25.1960    81.6594         Coal         Oil         NaN  ...
# 190   28.5787    77.6314        Solar         NaN         NaN  ...
#
#      year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 425                    NaN                  NaN                 NaN
# 381                 2019.0                  NaN            1393.879
# 757                    NaN                  NaN                 NaN
# 597                 2019.0                  NaN                 NaN
# 190                    NaN                  NaN                 NaN
#
#     generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 425                 NaN                 NaN                 NaN
# 381           1375.3480            1259.123            1090.750
# 757                 NaN                 NaN                 NaN
# 597            219.5193            4004.000            5155.986
# 190                 NaN                 NaN                 NaN
#
#      generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 425                  NaN                  NaN                            NaN
# 381              995.621                  NaN  Central Electricity Authority
# 757                  NaN                  NaN                            NaN
# 597             7200.400                  NaN  Central Electricity Authority
# 190                  NaN                  NaN                            NaN
#
#      estimated_generation_gwh
# 425                       NaN
# 381                       NaN
# 757                       NaN
# 597                       NaN
# 190                       NaN
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (907, 27)

# %% [markdown]
# We have 907 rows and 27 counts here in dataset

# %% [markdown]
# As we have hight columns range we will first try find out sum irrelevant coulumns and we can drop them

# %%
df.nunique()
# Out:
# country                       1
# country_long                  1
# name                        907
# gppd_idnr                   907
# capacity_mw                 361
# latitude                    836
# longitude                   827
# primary_fuel                  8
# other_fuel1                   3
# other_fuel2                   1
# other_fuel3                   0
# commissioning_year           73
# owner                       280
# source                      191
# url                         304
# geolocation_source            3
# wepp_id                       0
# year_of_capacity_data         1
# generation_gwh_2013           0
# generation_gwh_2014         371
# generation_gwh_2015         396
# generation_gwh_2016         403
# generation_gwh_2017         408
# generation_gwh_2018         410
# generation_gwh_2019           0
# generation_data_source        1
# estimated_generation_gwh      0
# dtype: int64

# %% [raw]
# I observed and found some irrelevant columns as pe below list. We will remove them.
#
# *country
# *country_long
# *other_fuel2
# *other_fuel3
# *wepp_id
# *year_of_capacity_data
# *generation_gwh_2013
# *generation_gwh_2019
# *generation_data_source
# *estimated_generation_gwh
#
# We found all above columns where we dont have either uniquenes or Null data. so we will drop them.

# %%
# Droping columns by making one list
list=['country','country_long','other_fuel2','other_fuel3','wepp_id','year_of_capacity_data','generation_gwh_2013','generation_gwh_2019','generation_data_source','estimated_generation_gwh']

df.drop(list,axis=1,inplace=True)
df
# Out:
#                              name   gppd_idnr  capacity_mw  latitude  \
# 0                ACME Solar Tower  WRI1020239          2.5   28.1839
# 1             ADITYA CEMENT WORKS  WRI1019881         98.0   24.7663
# 2        AES Saurashtra Windfarms  WRI1026669         39.2   21.9038
# 3                     AGARTALA GT  IND0000001        135.0   23.8712
# 4                    AKALTARA TPP  IND0000002       1800.0   21.9603
# ..                            ...         ...          ...       ...
# 902                  YERMARUS TPP  IND0000513       1600.0   16.2949
# 903  Yelesandra Solar Power Plant  WRI1026222          3.0   12.8932
# 904  Yelisirur wind power project  WRI1026776         25.5   15.2758
# 905                   ZAWAR MINES  WRI1019901         80.0   24.3500
# 906       iEnergy Theni Wind Farm  WRI1026761         16.5    9.9344
#
#      longitude primary_fuel other_fuel1  commissioning_year  \
# 0      73.2407        Solar         NaN              2011.0
# 1      74.6090         Coal         NaN                 NaN
# 2      69.3732         Wind         NaN                 NaN
# 3      91.3602          Gas         NaN              2004.0
# 4      82.4091         Coal         Oil              2015.0
# ..         ...          ...         ...                 ...
# 902    77.3568         Coal         Oil              2016.0
# 903    78.1654        Solar         NaN                 NaN
# 904    75.5811         Wind         NaN                 NaN
# 905    73.7477         Coal         NaN                 NaN
# 906    77.4768         Wind         NaN                 NaN
#
#                                    owner  \
# 0                            Solar Paces
# 1                   Ultratech Cement ltd
# 2                                    AES
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 902                                  NaN
# 903  Karnataka Power Corporation Limited
# 904                                  NaN
# 905                   Hindustan Zinc ltd
# 906                   iEnergy Wind Farms
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# 1                    Ultratech Cement ltd
# 2                                     CDM
# 3           Central Electricity Authority
# 4           Central Electricity Authority
# ..                                    ...
# 902         Central Electricity Authority
# 903   Karnataka Power Corporation Limited
# 904                                   CDM
# 905                    Hindustan Zinc ltd
# 906                                   CDM
#
#                                                    url  \
# 0    http://www.nrel.gov/csp/solarpaces/project_det...
# 1                      http://www.ultratechcement.com/
# 2    https://cdm.unfccc.int/Projects/DB/DNV-CUK1328...
# 3                               http://www.cea.nic.in/
# 4                               http://www.cea.nic.in/
# ..                                                 ...
# 902                             http://www.cea.nic.in/
# 903                          http://karnatakapower.com
# 904  https://cdm.unfccc.int/Projects/DB/TUEV-RHEIN1...
# 905                           http://www.hzlindia.com/
# 906  https://cdm.unfccc.int/Projects/DB/RWTUV134503...
#
#                        geolocation_source  generation_gwh_2014  \
# 0    National Renewable Energy Laboratory                  NaN
# 1                                     WRI                  NaN
# 2                                     WRI                  NaN
# 3                                     WRI           617.789264
# 4                                     WRI          3035.550000
# ..                                    ...                  ...
# 902                                   WRI                  NaN
# 903                        Industry About                  NaN
# 904                                   WRI                  NaN
# 905                                   WRI                  NaN
# 906                                   WRI                  NaN
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             843.747000           886.004428           663.774500
# 4            5916.370000          6243.000000          5385.579736
# ..                   ...                  ...                  ...
# 902             0.994875           233.596650           865.400000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2018
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3             626.239128
# 4            7279.000000
# ..                   ...
# 902           686.500000
# 903                  NaN
# 904                  NaN
# 905                  NaN
# 906                  NaN
#
# [907 rows x 17 columns]

# %%
df.shape
# Out:
# (907, 17)

# %% [markdown]
# We can see that 10 columns got reduced

# %%
df.isnull().sum()
# Out:
# name                     0
# gppd_idnr                0
# capacity_mw              0
# latitude                46
# longitude               46
# primary_fuel             0
# other_fuel1            709
# commissioning_year     380
# owner                  565
# source                   0
# url                      0
# geolocation_source      19
# generation_gwh_2014    509
# generation_gwh_2015    485
# generation_gwh_2016    473
# generation_gwh_2017    467
# generation_gwh_2018    459
# dtype: int64

# %% [markdown]
# We can see that we have highest missing data in other_furl1 and lowest missing in geolocation. We need to use imputing techniques to fill out those data.

# %%
df['other_fuel1'].value_counts()
# Out:
# Oil             195
# Gas               2
# Cogeneration      1
# Name: other_fuel1, dtype: int64

# %% [markdown]
# I would rather drop Other_fuel1 because as looking at the above number all Null values will be filled with Oil which will not make any sense.

# %%
df.drop('other_fuel1',axis=1,inplace=True)
df.isnull().sum()
# Out:
# name                     0
# gppd_idnr                0
# capacity_mw              0
# latitude                46
# longitude               46
# primary_fuel             0
# commissioning_year     380
# owner                  565
# source                   0
# url                      0
# geolocation_source      19
# generation_gwh_2014    509
# generation_gwh_2015    485
# generation_gwh_2016    473
# generation_gwh_2017    467
# generation_gwh_2018    459
# dtype: int64

# %%
count = df.nunique()
count
# Out:
# name                   907
# gppd_idnr              907
# capacity_mw            361
# latitude               836
# longitude              827
# primary_fuel             8
# commissioning_year      73
# owner                  280
# source                 191
# url                    304
# geolocation_source       3
# generation_gwh_2014    371
# generation_gwh_2015    396
# generation_gwh_2016    403
# generation_gwh_2017    408
# generation_gwh_2018    410
# dtype: int64

# %% [markdown]
# Looking at above counts and others colums I again Found some irrelevant data which we can drop from dataset.
#
# * name = every namen is unique
# * gppd_idnr = Every ID is unique
# * owner = we dont need owner name as we having  missing data and we can not impute any fake owners namen which will create bias.
# * Url = We dont need URL link

# %%
# Droping above columsn

list2=['name','gppd_idnr','owner','url']
df.drop(list2,axis=1,inplace=True)

# %%
df.shape
# Out:
# (907, 12)

# %%
df.loc[df['capacity_mw']==" "]
# Out:
# Empty DataFrame
# Columns: [capacity_mw, latitude, longitude, primary_fuel, commissioning_year, source, geolocation_source, generation_gwh_2014, generation_gwh_2015, generation_gwh_2016, generation_gwh_2017, generation_gwh_2018]
# Index: []

# %% [markdown]
# No Blank spaces are contain in Dataset

# %%
#Again checking missing values as we have delected so many unnecessary columns.

df.isnull().sum()
# Out:
# capacity_mw              0
# latitude                46
# longitude               46
# primary_fuel             0
# commissioning_year     380
# source                   0
# geolocation_source      19
# generation_gwh_2014    509
# generation_gwh_2015    485
# generation_gwh_2016    473
# generation_gwh_2017    467
# generation_gwh_2018    459
# dtype: int64

# %%
# Lets check datatypes so that we can get help to decide which imputing technique will work best

df.dtypes
# Out:
# capacity_mw            float64
# latitude               float64
# longitude              float64
# primary_fuel            object
# commissioning_year     float64
# source                  object
# geolocation_source      object
# generation_gwh_2014    float64
# generation_gwh_2015    float64
# generation_gwh_2016    float64
# generation_gwh_2017    float64
# generation_gwh_2018    float64
# dtype: object

# %% [raw]
# Below is the summary how we are going to treat our missing data accroding to Datatype
#
# latitude - Float - Mean
# longitude - Float - Median
# commissioning_year - Median
# geolocation_source - Mode
# generation_gwh_2014 - Knn Imputer
# generation_gwh_2015 -  Knn Imputer
# generation_gwh_2016 -  Knn Imputer
# generation_gwh_2017 -  Knn Imputer
# generation_gwh_2018 -   Knn Imputer

# %%
#Let start with mean median and mode imputing 

df["latitude"] = df["latitude"].fillna(df["latitude"].mean())
df["longitude"] = df["longitude"].fillna(df["longitude"].median())
df["commissioning_year"] = df["commissioning_year"].fillna(df["commissioning_year"].median())
df["geolocation_source"] = df["geolocation_source"].fillna(df["geolocation_source"].mode()[0])

# %%
# Imputing other remaining columsn with KNN Imputer

from sklearn.impute import KNNImputer
knnimp=KNNImputer(n_neighbors=3)
knn_imp=pd.DataFrame(knnimp.fit_transform(df[["capacity_mw","generation_gwh_2014"]]))
knn_imp.columns=["capacity_mw","generation_gwh_2014"]
knn_imp
# Out:
#      capacity_mw  generation_gwh_2014
# 0            2.5            16.779017
# 1           98.0           324.532517
# 2           39.2            85.185267
# 3          135.0           617.789264
# 4         1800.0          3035.550000
# ..           ...                  ...
# 902       1600.0          3691.517167
# 903          3.0            16.779017
# 904         25.5            16.779017
# 905         80.0           213.394333
# 906         16.5            16.779017
#
# [907 rows x 2 columns]

# %%
df["generation_gwh_2014"]=knn_imp["generation_gwh_2014"]
df['generation_gwh_2014']
# Out:
# 0        16.779017
# 1       324.532517
# 2        85.185267
# 3       617.789264
# 4      3035.550000
#           ...
# 902    3691.517167
# 903      16.779017
# 904      16.779017
# 905     213.394333
# 906      16.779017
# Name: generation_gwh_2014, Length: 907, dtype: float64

# %%
# As we did above for 2014, we will apply for all others
# For generation_with_2015
knn_imp=pd.DataFrame(knnimp.fit_transform(df[["capacity_mw","generation_gwh_2015"]]))
knn_imp.columns=["capacity_mw","generation_gwh_2015"]
df["generation_gwh_2015"]=knn_imp["generation_gwh_2015"]

#For generation_gwh_2016
knn_imp=pd.DataFrame(knnimp.fit_transform(df[["capacity_mw","generation_gwh_2016"]]))
knn_imp.columns=["capacity_mw","generation_gwh_2016"]
df["generation_gwh_2016"]=knn_imp["generation_gwh_2016"]

#For generation_gwh_2017
knn_imp=pd.DataFrame(knnimp.fit_transform(df[["capacity_mw","generation_gwh_2017"]]))
knn_imp.columns=["capacity_mw","generation_gwh_2017"]
df["generation_gwh_2017"]=knn_imp["generation_gwh_2017"]

#For generation_gwh_2018
knn_imp=pd.DataFrame(knnimp.fit_transform(df[["capacity_mw","generation_gwh_2018"]]))
knn_imp.columns=["capacity_mw","generation_gwh_2018"]
df["generation_gwh_2018"]=knn_imp["generation_gwh_2018"]

# %%
df
# Out:
#      capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407        Solar              2011.0
# 1           98.0   24.7663    74.6090         Coal              2001.0
# 2           39.2   21.9038    69.3732         Wind              2001.0
# 3          135.0   23.8712    91.3602          Gas              2004.0
# 4         1800.0   21.9603    82.4091         Coal              2015.0
# ..           ...       ...        ...          ...                 ...
# 902       1600.0   16.2949    77.3568         Coal              2016.0
# 903          3.0   12.8932    78.1654        Solar              2001.0
# 904         25.5   15.2758    75.5811         Wind              2001.0
# 905         80.0   24.3500    73.7477         Coal              2001.0
# 906         16.5    9.9344    77.4768         Wind              2001.0
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# 1                    Ultratech Cement ltd
# 2                                     CDM
# 3           Central Electricity Authority
# 4           Central Electricity Authority
# ..                                    ...
# 902         Central Electricity Authority
# 903   Karnataka Power Corporation Limited
# 904                                   CDM
# 905                    Hindustan Zinc ltd
# 906                                   CDM
#
#                        geolocation_source  generation_gwh_2014  \
# 0    National Renewable Energy Laboratory            16.779017
# 1                                     WRI           324.532517
# 2                                     WRI            85.185267
# 3                                     WRI           617.789264
# 4                                     WRI          3035.550000
# ..                                    ...                  ...
# 902                                   WRI          3691.517167
# 903                        Industry About            16.779017
# 904                                   WRI            16.779017
# 905                                   WRI           213.394333
# 906                                   WRI            16.779017
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0              13.293200             8.974900            22.244883
# 1             168.964267           230.073850           210.319783
# 2             112.481433           114.819683           185.902483
# 3             843.747000           886.004428           663.774500
# 4            5916.370000          6243.000000          5385.579736
# ..                   ...                  ...                  ...
# 902             0.994875           233.596650           865.400000
# 903            13.293200             8.974900            22.244883
# 904            13.293200             8.974900            22.244883
# 905           187.315383           216.123950           243.171367
# 906            13.293200             8.974900            22.244883
#
#      generation_gwh_2018
# 0              47.968950
# 1             299.083733
# 2             198.180783
# 3             626.239128
# 4            7279.000000
# ..                   ...
# 902           686.500000
# 903            47.968950
# 904            47.968950
# 905           256.620450
# 906            47.968950
#
# [907 rows x 12 columns]

# %%
# Checking Null value now

df.isnull().sum()
# Out:
# capacity_mw            0
# latitude               0
# longitude              0
# primary_fuel           0
# commissioning_year     0
# source                 0
# geolocation_source     0
# generation_gwh_2014    0
# generation_gwh_2015    0
# generation_gwh_2016    0
# generation_gwh_2017    0
# generation_gwh_2018    0
# dtype: int64

# %% [markdown]
# We treated all null value with feasible methods accordingly to type of data

# %%
# Now let us visualise the image

sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
print(df["primary_fuel"].value_counts())
labels='Coal','Hydro','Solar','Wind','Gas','Biomass','Oil','Nuclear'
fig, ax = plt.subplots(figsize=(10,8))
ax.pie(df['primary_fuel'].value_counts(),labels=labels,  autopct='%1.2f%%', shadow=True)
plt.show()
# Out:
# Coal       258
# Hydro      251
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         20
# Nuclear      9
# Name: primary_fuel, dtype: int64

# %% [markdown]
# We can simpy have look on above chart where we can see Highest Energy we are getting from hydro and second highest in Coal. Nuclear energy has least contribution here.

# %%
sns.countplot(x='primary_fuel',data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='count'>

# %% [markdown]
# Looking same info using count plot here

# %%
sns.countplot(x='geolocation_source',data=df)
# Out:
# <AxesSubplot:xlabel='geolocation_source', ylabel='count'>

# %% [markdown]
# WRI Location is most repeated Location

# %%
plt.figure(figsize=(10,7))
sns.violinplot(x="primary_fuel", y="capacity_mw", data=df, 
              split=True, scale="count", inner="quartile")
plt.show()

# %% [markdown]
# We can see from above plot that Coal is the highest contributor even in energy capicity and Nuclear is the lowestr again

# %%
generation_in_2014=float(pd.Series(df['generation_gwh_2014'].sum()))
generation_in_2015=float(pd.Series(df['generation_gwh_2015'].sum()))
generation_in_2016=float(pd.Series(df['generation_gwh_2016'].sum()))
generation_in_2017=float(pd.Series(df['generation_gwh_2017'].sum()))

Yearly={"years":[generation_in_2014,generation_in_2015,generation_in_2016,generation_in_2017]}

yr=pd.DataFrame(Yearly)

# Ploting yearly trend of Generation.
plt.figure(figsize=(10,7))
sns.countplot(x='years',data=yr)
# Out:
# <AxesSubplot:xlabel='years', ylabel='count'>

# %% [markdown]
# We can see energy production is almost same for every year ther is no big change.

# %%
sns.scatterplot
sns.scatterplot(x="latitude",y="capacity_mw",data=df)
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='capacity_mw'>

# %% [markdown]
# We can see lattitude is equally distributed or else not have any linearity

# %%
sns.scatterplot
sns.scatterplot(x="primary_fuel",y="capacity_mw",data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='capacity_mw'>

# %% [markdown]
# Again we can see same trend as we have seen previously like Coal is highest and Biomass and Nuclear lower side

# %%
sns.scatterplot
sns.scatterplot(x="generation_gwh_2014",y="capacity_mw",data=df)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2014', ylabel='capacity_mw'>

# %%
sns.scatterplot
sns.scatterplot(x="generation_gwh_2015",y="capacity_mw",data=df)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2015', ylabel='capacity_mw'>

# %%
sns.scatterplot
sns.scatterplot(x="generation_gwh_2016",y="capacity_mw",data=df)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2016', ylabel='capacity_mw'>

# %%
sns.scatterplot
sns.scatterplot(x="generation_gwh_2017",y="capacity_mw",data=df)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2017', ylabel='capacity_mw'>

# %% [markdown]
# so looking at all years growth we cans ee that ther is perfect linearity and postive realtiomn between both.

# %% [markdown]
# We are done with visualization part to understand data better. Alomost all columns we have trid to compare.

# %%
sns.pairplot(df)

# %% [markdown]
# We can see that year are having good linearity which will help us to perform good prediction for target variable

# %% [markdown]
# # Discriptive statistics

# %%
df.describe().T
# Out:
#                      count         mean          std        min          25%  \
# capacity_mw          907.0   326.223755   590.085456     0.0000    16.725000
# latitude             907.0    21.197918     6.079148     8.1689    17.072000
# longitude            907.0    77.427103     4.815073    68.6447    74.388900
# commissioning_year   907.0  1998.728776    13.158621  1927.0000  1998.000000
# generation_gwh_2014  907.0  1216.741950  2944.274717     0.0000    16.779017
# generation_gwh_2015  907.0  1225.038756  3119.378830     0.0000    13.293200
# generation_gwh_2016  907.0  1247.732255  3138.627167     0.0000     8.974900
# generation_gwh_2017  907.0  1294.294476  3187.955950     0.0000    22.244883
# generation_gwh_2018  907.0  1348.291762  3293.148855     0.0000    47.968950
#
#                              50%          75%        max
# capacity_mw            59.200000   385.250000   4760.000
# latitude               21.281800    25.176450     34.649
# longitude              76.719500    79.206100     95.408
# commissioning_year   2001.000000  2003.000000   2018.000
# generation_gwh_2014   171.853083   926.055500  28127.000
# generation_gwh_2015   139.546801   735.113025  30539.000
# generation_gwh_2016   132.842450   780.149650  30015.000
# generation_gwh_2017   128.822650   817.977250  35116.000
# generation_gwh_2018   133.912800   810.733240  35136.000

# %% [markdown]
# From above stats we can see that ther might be possiblity of skewnesss and outliers present in data as  Max and min columns there is huge differences

# %%
# Looking fo rcorrelation

df.corr()
# Out:
#                      capacity_mw  latitude  longitude  commissioning_year  \
# capacity_mw             1.000000  0.050984   0.199299            0.211042
# latitude                0.050984  1.000000   0.036341            0.087937
# longitude               0.199299  0.036341   1.000000            0.029583
# commissioning_year      0.211042  0.087937   0.029583            1.000000
# generation_gwh_2014     0.856402  0.056823   0.161994            0.095893
# generation_gwh_2015     0.865556  0.053364   0.163402            0.114837
# generation_gwh_2016     0.887576  0.049540   0.183385            0.137594
# generation_gwh_2017     0.900910  0.057954   0.195420            0.146887
# generation_gwh_2018     0.912287  0.054626   0.192411            0.150541
#
#                      generation_gwh_2014  generation_gwh_2015  \
# capacity_mw                     0.856402             0.865556
# latitude                        0.056823             0.053364
# longitude                       0.161994             0.163402
# commissioning_year              0.095893             0.114837
# generation_gwh_2014             1.000000             0.959108
# generation_gwh_2015             0.959108             1.000000
# generation_gwh_2016             0.937960             0.974137
# generation_gwh_2017             0.916587             0.946383
# generation_gwh_2018             0.909878             0.942578
#
#                      generation_gwh_2016  generation_gwh_2017  \
# capacity_mw                     0.887576             0.900910
# latitude                        0.049540             0.057954
# longitude                       0.183385             0.195420
# commissioning_year              0.137594             0.146887
# generation_gwh_2014             0.937960             0.916587
# generation_gwh_2015             0.974137             0.946383
# generation_gwh_2016             1.000000             0.974368
# generation_gwh_2017             0.974368             1.000000
# generation_gwh_2018             0.966327             0.987739
#
#                      generation_gwh_2018
# capacity_mw                     0.912287
# latitude                        0.054626
# longitude                       0.192411
# commissioning_year              0.150541
# generation_gwh_2014             0.909878
# generation_gwh_2015             0.942578
# generation_gwh_2016             0.966327
# generation_gwh_2017             0.987739
# generation_gwh_2018             1.000000

# %%
#Plotting correaltion on heatmap to visualize better

import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), annot=True, linewidths=0.6,linecolor="black", fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# So I observed one thing in above heatmap that there is no any negative corraltion present in dataset.

# %%
# Lets Handle our our object by coverting then into number 

# Handling Objest using LabelEncoder

from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

list=['primary_fuel','source','geolocation_source']

for i in list:
    df[i]=le.fit_transform(df[i].astype(str))
    
df.head()
# Out:
#    capacity_mw  latitude  longitude  primary_fuel  commissioning_year  source  \
# 0          2.5   28.1839    73.2407             6              2011.0     109
# 1         98.0   24.7663    74.6090             1              2001.0     174
# 2         39.2   21.9038    69.3732             7              2001.0      21
# 3        135.0   23.8712    91.3602             2              2004.0      22
# 4       1800.0   21.9603    82.4091             1              2015.0      22
#
#    geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# 0                   1            16.779017            13.293200
# 1                   2           324.532517           168.964267
# 2                   2            85.185267           112.481433
# 3                   2           617.789264           843.747000
# 4                   2          3035.550000          5916.370000
#
#    generation_gwh_2016  generation_gwh_2017  generation_gwh_2018
# 0             8.974900            22.244883            47.968950
# 1           230.073850           210.319783           299.083733
# 2           114.819683           185.902483           198.180783
# 3           886.004428           663.774500           626.239128
# 4          6243.000000          5385.579736          7279.000000

# %%
df.hist(figsize=(25,30))
plt.show()

# %% [markdown]
# Lattitudue  and longitute are the one good distibuted but those not much effective.

# %%
# Lets see correlation with our target column

df.corr()['capacity_mw'].sort_values()
# Out:
# primary_fuel          -0.380395
# source                -0.242122
# latitude               0.050984
# longitude              0.199299
# geolocation_source     0.204865
# commissioning_year     0.211042
# generation_gwh_2014    0.856402
# generation_gwh_2015    0.865556
# generation_gwh_2016    0.887576
# generation_gwh_2017    0.900910
# generation_gwh_2018    0.912287
# capacity_mw            1.000000
# Name: capacity_mw, dtype: float64

# %%
plt.figure(figsize=(22,7))
df.corr()['capacity_mw'].sort_values(ascending=False).drop(['capacity_mw']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('target',fontsize=14)
plt.title('correlation between label and feature using bar plot',fontsize=18)
plt.show()

# %%
# Its ok to drop latitude as both are location cordinatore and longitue will help us if required

df.drop('latitude',axis=1,inplace=True)

# %%
plt.figure(figsize=(20,25))

graph=1

for i in df:
    if graph<=11:
        plt.subplot(7,4,graph)
        sns.boxplot(data=df[i])
        plt.xlabel(i)
    graph+=1    
    
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# We have outliers present in dataset which we will try to handle now

# %%
# Lets treat outliers now

from scipy.stats import zscore
zscore=zscore(df)
zabs=np.abs(zscore)

z=df[(zabs<3).all(axis=1)]

# %%
z.shape
# Out:
# (831, 11)

# %%
df.shape
# Out:
# (907, 11)

# %%
loss=(907-833)/907*100
loss
# Out:
# 8.158765159867695

# %%
dropindex=df.index.difference(z.index)
dropindex
# Out:
# Int64Index([ 15,  71,  80, 143, 147, 158, 179, 183, 191, 209, 219, 222, 244,
#             299, 308, 321, 323, 333, 340, 342, 345, 360, 363, 364, 371, 375,
#             414, 416, 427, 444, 454, 478, 482, 484, 493, 494, 499, 519, 532,
#             538, 541, 546, 573, 577, 583, 592, 601, 621, 638, 648, 657, 661,
#             669, 689, 695, 706, 709, 721, 724, 726, 728, 767, 786, 788, 807,
#             808, 818, 832, 847, 848, 870, 871, 879, 880, 895, 900],
#            dtype='int64')

# %%
df.drop(dropindex,inplace=True)
df
# Out:
#      capacity_mw  longitude  primary_fuel  commissioning_year  source  \
# 0            2.5    73.2407             6              2011.0     109
# 1           98.0    74.6090             1              2001.0     174
# 2           39.2    69.3732             7              2001.0      21
# 3          135.0    91.3602             2              2004.0      22
# 4         1800.0    82.4091             1              2015.0      22
# ..           ...        ...           ...                 ...     ...
# 902       1600.0    77.3568             1              2016.0      22
# 903          3.0    78.1654             6              2001.0      77
# 904         25.5    75.5811             7              2001.0      21
# 905         80.0    73.7477             1              2001.0      59
# 906         16.5    77.4768             7              2001.0      21
#
#      geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# 0                     1            16.779017            13.293200
# 1                     2           324.532517           168.964267
# 2                     2            85.185267           112.481433
# 3                     2           617.789264           843.747000
# 4                     2          3035.550000          5916.370000
# ..                  ...                  ...                  ...
# 902                   2          3691.517167             0.994875
# 903                   0            16.779017            13.293200
# 904                   2            16.779017            13.293200
# 905                   2           213.394333           187.315383
# 906                   2            16.779017            13.293200
#
#      generation_gwh_2016  generation_gwh_2017  generation_gwh_2018
# 0               8.974900            22.244883            47.968950
# 1             230.073850           210.319783           299.083733
# 2             114.819683           185.902483           198.180783
# 3             886.004428           663.774500           626.239128
# 4            6243.000000          5385.579736          7279.000000
# ..                   ...                  ...                  ...
# 902           233.596650           865.400000           686.500000
# 903             8.974900            22.244883            47.968950
# 904             8.974900            22.244883            47.968950
# 905           216.123950           243.171367           256.620450
# 906             8.974900            22.244883            47.968950
#
# [831 rows x 11 columns]

# %%
plt.figure(figsize=(20,25))

graph=1

for i in df:
    if graph<=28:
        plt.subplot(7,4,graph)
        sns.boxplot(data=df[i])
        plt.xlabel(i)
    graph+=1    
    
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# We trated outliers at best level now we can go ahead

# %%
df.skew()
# Out:
# capacity_mw            1.951057
# longitude              0.938759
# primary_fuel           0.410410
# commissioning_year    -1.269233
# source                 1.782016
# geolocation_source    -2.098153
# generation_gwh_2014    2.572654
# generation_gwh_2015    2.548850
# generation_gwh_2016    2.533623
# generation_gwh_2017    2.465869
# generation_gwh_2018    2.500417
# dtype: float64

# %%
#We have some skewness present as we can see in above values
#Lest plot them

# Ploting on graph to better visualization

plt.figure(figsize=(20,25),facecolor="white")

plot=1

for i in df:
    if plot<=11:
        plt.subplot(7,4,plot)
        sns.distplot(df[i])
        plt.xlabel(i)
    plot+=1    
    
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Many of the columsn have skewness in data which we need to treat letter on

# %% [markdown]
# Saving Same data for classification problem as we need to predict Primary Fuel after regression

# %%
Class_df=df

# %% [markdown]
# # Defining x and y

# %%
x = df.drop("capacity_mw", axis=1)
y = df["capacity_mw"]

# %%
x.shape
# Out:
# (831, 10)

# %%
y.shape
# Out:
# (831,)

# %% [markdown]
# # Removing Skewness using yeo-johnson method

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[-0.91945232,  1.12891637,  1.14710477, ..., -0.94480241,
#         -0.78772714, -0.64029575],
#        [-0.49991346, -1.01957309,  0.00272329, ...,  0.39936651,
#          0.23748227,  0.24458698],
#        [-2.36290205,  1.40292106,  0.00272329, ...,  0.11889311,
#          0.18183099,  0.04125527],
#        ...,
#        [-0.22595492,  1.40292106,  0.00272329, ..., -0.94480241,
#         -0.78772714, -0.64029575],
#        [-0.75912871, -1.01957309,  0.00272329, ...,  0.37441181,
#          0.30277018,  0.16866596],
#        [ 0.25714638,  1.40292106,  0.00272329, ..., -0.94480241,
#         -0.78772714, -0.64029575]])

# %%
df.columns
# Out:
# Index(['capacity_mw', 'longitude', 'primary_fuel', 'commissioning_year',
#        'source', 'geolocation_source', 'generation_gwh_2014',
#        'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017',
#        'generation_gwh_2018'],
#       dtype='object')

# %%
Columnsname=['longitude', 'primary_fuel', 'commissioning_year',
       'source', 'geolocation_source', 'generation_gwh_2014',
       'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017',
       'generation_gwh_2018']

# %%
new_x=pd.DataFrame(data=x,columns=Columnsname)

plt.figure(figsize=(20,25),facecolor='white')

plotn=1

for col in new_x:
    if plotn<=10:
        plt.subplot(7,4,plotn)
        sns.distplot(new_x[col])
        plt.xlabel(col,fontsize=15)
        
    plotn+=1   
    
plt.show()

# %% [markdown]
# We have trated skewness now and ready to go ahead for train model

# %%
# Scalling data is always best pratice hence applying standered scaler 

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=Columnsname)
x.head()
# Out:
#    longitude  primary_fuel  commissioning_year    source  geolocation_source  \
# 0  -0.919452      1.128916            1.147105  1.613478           -2.275247
# 1  -0.499913     -1.019573            0.002723  2.087255            0.404765
# 2  -2.362902      1.402921            0.002723 -0.467780            0.404765
# 3   2.428670     -0.400698            0.318968 -0.399668            0.404765
# 4   1.256600     -1.019573            1.683296 -0.399668            0.404765
#
#    generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0            -0.897785            -0.889530            -0.944802
# 1             0.412827             0.228256             0.399367
# 2            -0.181427             0.052900             0.118893
# 3             0.697166             0.898668             0.922871
# 4             1.393397             1.660129             1.631917
#
#    generation_gwh_2017  generation_gwh_2018
# 0            -0.787727            -0.640296
# 1             0.237482             0.244587
# 2             0.181831             0.041255
# 3             0.749300             0.615276
# 4             1.649018             1.894674

# %%
# Basically we dont need to check VIF as there in high dimensional data but still lest have look once

import statsmodels.api as sm
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['Features'] = x.columns
vif['VIF values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif
# Out:
#               Features  VIF values
# 0            longitude    1.277801
# 1         primary_fuel    1.663942
# 2   commissioning_year    1.085909
# 3               source    1.380238
# 4   geolocation_source    1.672565
# 5  generation_gwh_2014    4.173628
# 6  generation_gwh_2015    6.498522
# 7  generation_gwh_2016   11.441306
# 8  generation_gwh_2017    7.227318
# 9  generation_gwh_2018    6.233722

# %% [markdown]
# Only one colums generation_gwh_2016 found as VIF above 10 but we should not remove it as we already have less columns

# %%
# Now we will import required liabraries and models to traine our multiple models.

import sklearn
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

#metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score

# %%
maxAcc = 0
maxRS = 0

for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20, random_state=i)
    modRF = RandomForestRegressor()
    modRF.fit(x_train,y_train)
    pred = modRF.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxAcc:
        maxAcc = acc
        maxRs=i
print(f"Best Accuracy is: {maxAcc} on Random State: {maxRs}")
# Out:
# Best Accuracy is: 0.9194202134285322 on Random State: 121

# %% [markdown]
# So we found best random state as 5 which will give us approx 91% accuracy

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

dt=DecisionTreeRegressor()
kn=KNeighborsRegressor()
adb=AdaBoostRegressor()
gdb=GradientBoostingRegressor()
lnr=LinearRegression()
rfr=RandomForestRegressor()
sv=SVR()
lss=Lasso(alpha=10)

model=[dt,kn,adb,gdb,lnr,rfr,sv,lss]

for i in model:
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20, random_state=121)
    i.fit(x_train,y_train)
    predi=i.predict(x_test)
    print('performance matrix of',i,'is:')
    print("RMSE Score is:",mean_squared_error(y_test,predi))
    print('MAE:',mean_absolute_error(y_test, predi))
    print('MSE:',mean_squared_error(y_test, predi))
    r2 = r2_score(y_test, predi)*100
    print("R2 Score is:", r2)
    cv_score = (cross_val_score(i, x, y, cv=5).mean())*100
    print("Cross Validation Score:", cv_score)
    result = r2 - cv_score
    print("R2 Score - Cross Validation Score is", result)
    print("*****************************************************************")
# Out:
# performance matrix of DecisionTreeRegressor() is:
# RMSE Score is: 49641.41261338921
# MAE: 99.23356886227546
# MSE: 49641.41261338921
# R2 Score is: 72.50985188036469
# Cross Validation Score: 68.41084589047728
# R2 Score - Cross Validation Score is 4.0990059898874165
# *****************************************************************
# performance matrix of KNeighborsRegressor() is:
# RMSE Score is: 25330.524236518562
# MAE: 85.07604431137726
# MSE: 25330.524236518562
# R2 Score is: 85.97260177438845
# Cross Validation Score: 77.3468685938972
# R2 Score - Cross Validation Score is 8.625733180491252
# *****************************************************************
# performance matrix of AdaBoostRegressor() is:
# RMSE Score is: 44631.864291187114
# MAE: 195.9484080458454
# MSE: 44631.864291187114
# R2 Score is: 75.28401196445269
# Cross Validation Score: 66.23125555059104
# R2 Score - Cross Validation Score is 9.052756413861644
# *****************************************************************
# performance matrix of GradientBoostingRegressor() is:
# RMSE Score is: 27704.025710853068
# MAE: 82.90764163470418
# MSE: 27704.025710853068
# R2 Score is: 84.65821719795055
# Cross Validation Score: 81.8137019675628
# R2 Score - Cross Validation Score is 2.844515230387742
# *****************************************************************
# performance matrix of LinearRegression() is:
# RMSE Score is: 58698.75733653799
# MAE: 176.1774687098002
# MSE: 58698.75733653799
# R2 Score is: 67.49412539511958
# Cross Validation Score: 53.72526361172836
# R2 Score - Cross Validation Score is 13.768861783391223
# *****************************************************************
# performance matrix of RandomForestRegressor() is:
# RMSE Score is: 15008.159754584009
# MAE: 64.2234353206956
# MSE: 15008.159754584009
# R2 Score is: 91.68886393564505
# Cross Validation Score: 83.80994419694603
# R2 Score - Cross Validation Score is 7.878919738699011
# *****************************************************************
# performance matrix of SVR() is:
# RMSE Score is: 183845.81192105683
# MAE: 211.63500033366267
# MSE: 183845.81192105683
# R2 Score is: -1.8091213528706351
# Cross Validation Score: -2.2771094783380663
# R2 Score - Cross Validation Score is 0.4679881254674312
# *****************************************************************
# performance matrix of Lasso(alpha=10) is:
# RMSE Score is: 59839.13601929387
# MAE: 175.89651679179144
# MSE: 59839.13601929387
# R2 Score is: 66.86261276783834
# Cross Validation Score: 53.62589159650187
# R2 Score - Cross Validation Score is 13.23672117133647
# *****************************************************************

# %% [markdown]
# Looking at the above matrix we can see that GradientBoostingRegressor is wroking good because we can see that difference between R2 score and Cross Validation is only 2.8 which is least differnce among all Model and have 84% Accuracy

# %% [markdown]
# # HYPERPARAMETR TUNING FOR GradientBoostingRegressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={'loss' : ['squared_error', 'absolute_error', 'huber', 'quantile'],
           'max_features' : ['auto', 'sqrt', 'log2'],
           'learning_rate':[0.1,.2,.4,.5],
           'criterion' : ['friedman_mse', 'squared_error', 'mse'],}


GCV=GridSearchCV(GradientBoostingRegressor(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['friedman_mse', 'squared_error', 'mse'],
#                          'learning_rate': [0.1, 0.2, 0.4, 0.5],
#                          'loss': ['squared_error', 'absolute_error', 'huber',
#                                   'quantile'],
#                          'max_features': ['auto', 'sqrt', 'log2']})

# %%
GCV.best_params_
# Out:
# {'criterion': 'squared_error',
#  'learning_rate': 0.2,
#  'loss': 'huber',
#  'max_features': 'log2'}

# %%
capacity_model = GradientBoostingRegressor(criterion='squared_error', learning_rate= 0.2, loss= 'huber',max_features= 'log2')
capacity_model.fit(x_train, y_train)
pred = capacity_model.predict(x_test)
print("RMSE value:",np.sqrt(mean_squared_error(y_test, gdb.predict(x_test))))
print('R2_Score:',r2_score(y_test,pred)*100)
# Out:
# RMSE value: 166.44526340768329
# R2_Score: 89.57939489029822

# %% [markdown]
# We have increased accuracy with 5 % which is good and our final model is scoring 89.5% Accuracy

# %%
#saving the model 
import joblib
joblib.dump(capacity_model,'Power_capicity.pkl')
# Out:
# ['Power_capicity.pkl']

# %%
# Loading our saved model so that we can predict using it

loadmodel = joblib.load('Power_capicity.pkl')

# %%
import numpy as np
a = np.array(y_test)
predicted = np.array(loadmodel.predict(x_test))
df_final = pd.DataFrame({"Original":a,"Predicted":predicted},index=range(len(a)))
df_final
# Out:
#      Original    Predicted
# 0       14.65    14.867947
# 1      246.00   134.943493
# 2       22.80    17.809893
# 3       10.50     9.451213
# 4        4.00    10.770651
# ..        ...          ...
# 162     42.00    71.041199
# 163   1980.00  1337.435837
# 164   1200.00   723.643487
# 165     25.20   104.586580
# 166     15.20    11.102030
#
# [167 rows x 2 columns]

# %%
print('R2_Score:',r2_score(y_test,predicted)*100)
# Out:
# R2_Score: 89.57939489029822

# %% [markdown]
# Again checking R2 score just to validate if our model is Overfitting or not. we get here expected value as trained so there is no Over or underfitting chances here

# %% [markdown]
# # Classification model to predict Primary Fuel

# %%
# This Dataset we have already saved previously in this jupyter book after removing outliers

Class_df
# Out:
#      capacity_mw  longitude  primary_fuel  commissioning_year  source  \
# 0            2.5    73.2407             6              2011.0     109
# 1           98.0    74.6090             1              2001.0     174
# 2           39.2    69.3732             7              2001.0      21
# 3          135.0    91.3602             2              2004.0      22
# 4         1800.0    82.4091             1              2015.0      22
# ..           ...        ...           ...                 ...     ...
# 902       1600.0    77.3568             1              2016.0      22
# 903          3.0    78.1654             6              2001.0      77
# 904         25.5    75.5811             7              2001.0      21
# 905         80.0    73.7477             1              2001.0      59
# 906         16.5    77.4768             7              2001.0      21
#
#      geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# 0                     1            16.779017            13.293200
# 1                     2           324.532517           168.964267
# 2                     2            85.185267           112.481433
# 3                     2           617.789264           843.747000
# 4                     2          3035.550000          5916.370000
# ..                  ...                  ...                  ...
# 902                   2          3691.517167             0.994875
# 903                   0            16.779017            13.293200
# 904                   2            16.779017            13.293200
# 905                   2           213.394333           187.315383
# 906                   2            16.779017            13.293200
#
#      generation_gwh_2016  generation_gwh_2017  generation_gwh_2018
# 0               8.974900            22.244883            47.968950
# 1             230.073850           210.319783           299.083733
# 2             114.819683           185.902483           198.180783
# 3             886.004428           663.774500           626.239128
# 4            6243.000000          5385.579736          7279.000000
# ..                   ...                  ...                  ...
# 902           233.596650           865.400000           686.500000
# 903             8.974900            22.244883            47.968950
# 904             8.974900            22.244883            47.968950
# 905           216.123950           243.171367           256.620450
# 906             8.974900            22.244883            47.968950
#
# [831 rows x 11 columns]

# %%
# Looking fo rcorrelation

Class_df.corr()
# Out:
#                      capacity_mw  longitude  primary_fuel  commissioning_year  \
# capacity_mw             1.000000   0.268518     -0.416169            0.222108
# longitude               0.268518   1.000000     -0.395096            0.079480
# primary_fuel           -0.416169  -0.395096      1.000000           -0.067088
# commissioning_year      0.222108   0.079480     -0.067088            1.000000
# source                 -0.279235  -0.246198      0.062580            0.080390
# geolocation_source      0.239658   0.272511     -0.470437           -0.055148
# generation_gwh_2014     0.783927   0.222038     -0.362830            0.087083
# generation_gwh_2015     0.789824   0.225979     -0.359637            0.122525
# generation_gwh_2016     0.845691   0.257201     -0.367637            0.175455
# generation_gwh_2017     0.858649   0.264453     -0.367865            0.186023
# generation_gwh_2018     0.860508   0.265922     -0.365065            0.182540
#
#                        source  geolocation_source  generation_gwh_2014  \
# capacity_mw         -0.279235            0.239658             0.783927
# longitude           -0.246198            0.272511             0.222038
# primary_fuel         0.062580           -0.470437            -0.362830
# commissioning_year   0.080390           -0.055148             0.087083
# source               1.000000           -0.521385            -0.234858
# geolocation_source  -0.521385            1.000000             0.199917
# generation_gwh_2014 -0.234858            0.199917             1.000000
# generation_gwh_2015 -0.229861            0.195501             0.907156
# generation_gwh_2016 -0.230741            0.196040             0.842664
# generation_gwh_2017 -0.231757            0.195008             0.818411
# generation_gwh_2018 -0.228264            0.193003             0.812976
#
#                      generation_gwh_2015  generation_gwh_2016  \
# capacity_mw                     0.789824             0.845691
# longitude                       0.225979             0.257201
# primary_fuel                   -0.359637            -0.367637
# commissioning_year              0.122525             0.175455
# source                         -0.229861            -0.230741
# geolocation_source              0.195501             0.196040
# generation_gwh_2014             0.907156             0.842664
# generation_gwh_2015             1.000000             0.931857
# generation_gwh_2016             0.931857             1.000000
# generation_gwh_2017             0.872417             0.942092
# generation_gwh_2018             0.867745             0.933290
#
#                      generation_gwh_2017  generation_gwh_2018
# capacity_mw                     0.858649             0.860508
# longitude                       0.264453             0.265922
# primary_fuel                   -0.367865            -0.365065
# commissioning_year              0.186023             0.182540
# source                         -0.231757            -0.228264
# geolocation_source              0.195008             0.193003
# generation_gwh_2014             0.818411             0.812976
# generation_gwh_2015             0.872417             0.867745
# generation_gwh_2016             0.942092             0.933290
# generation_gwh_2017             1.000000             0.973264
# generation_gwh_2018             0.973264             1.000000

# %%
#Plotting correaltion on heatmap to visualize better

import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
sns.heatmap(Class_df.corr(), annot=True, linewidths=0.6,linecolor="black", fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see that source that most of coulums are negatively correlatited with primary fuel which is our target variable.

# %%
# Lets see correlation with our target variable separatly

Class_df.corr()['primary_fuel'].sort_values()
# Out:
# geolocation_source    -0.470437
# capacity_mw           -0.416169
# longitude             -0.395096
# generation_gwh_2017   -0.367865
# generation_gwh_2016   -0.367637
# generation_gwh_2018   -0.365065
# generation_gwh_2014   -0.362830
# generation_gwh_2015   -0.359637
# commissioning_year    -0.067088
# source                 0.062580
# primary_fuel           1.000000
# Name: primary_fuel, dtype: float64

# %% [markdown]
# As we can see all are negative

# %%
plt.figure(figsize=(22,7))
Class_df.corr()['primary_fuel'].sort_values(ascending=False).drop(['primary_fuel']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('target',fontsize=14)
plt.title('correlation between label and feature using bar plot',fontsize=18)
plt.show()

# %%
#We can drop source here

Class_df.drop('source',axis=1,inplace=True)
Class_df
# Out:
#      capacity_mw  longitude  primary_fuel  commissioning_year  \
# 0            2.5    73.2407             6              2011.0
# 1           98.0    74.6090             1              2001.0
# 2           39.2    69.3732             7              2001.0
# 3          135.0    91.3602             2              2004.0
# 4         1800.0    82.4091             1              2015.0
# ..           ...        ...           ...                 ...
# 902       1600.0    77.3568             1              2016.0
# 903          3.0    78.1654             6              2001.0
# 904         25.5    75.5811             7              2001.0
# 905         80.0    73.7477             1              2001.0
# 906         16.5    77.4768             7              2001.0
#
#      geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# 0                     1            16.779017            13.293200
# 1                     2           324.532517           168.964267
# 2                     2            85.185267           112.481433
# 3                     2           617.789264           843.747000
# 4                     2          3035.550000          5916.370000
# ..                  ...                  ...                  ...
# 902                   2          3691.517167             0.994875
# 903                   0            16.779017            13.293200
# 904                   2            16.779017            13.293200
# 905                   2           213.394333           187.315383
# 906                   2            16.779017            13.293200
#
#      generation_gwh_2016  generation_gwh_2017  generation_gwh_2018
# 0               8.974900            22.244883            47.968950
# 1             230.073850           210.319783           299.083733
# 2             114.819683           185.902483           198.180783
# 3             886.004428           663.774500           626.239128
# 4            6243.000000          5385.579736          7279.000000
# ..                   ...                  ...                  ...
# 902           233.596650           865.400000           686.500000
# 903             8.974900            22.244883            47.968950
# 904             8.974900            22.244883            47.968950
# 905           216.123950           243.171367           256.620450
# 906             8.974900            22.244883            47.968950
#
# [831 rows x 10 columns]

# %% [markdown]
# # Defining x and y

# %%
x = Class_df.drop("primary_fuel", axis=1)
y = Class_df["primary_fuel"]

# %%
x.shape
# Out:
# (831, 9)

# %%
y.shape
# Out:
# (831,)

# %% [markdown]
# # Removing Skewness using yeo-johnson method

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[-1.67077503, -0.91945232,  1.14710477, ..., -0.94480241,
#         -0.78772714, -0.64029575],
#        [ 0.21283109, -0.49991346,  0.00272329, ...,  0.39936651,
#          0.23748227,  0.24458698],
#        [-0.28360251, -2.36290205,  0.00272329, ...,  0.11889311,
#          0.18183099,  0.04125527],
#        ...,
#        [-0.51597228, -0.22595492,  0.00272329, ..., -0.94480241,
#         -0.78772714, -0.64029575],
#        [ 0.10301538, -0.75912871,  0.00272329, ...,  0.37441181,
#          0.30277018,  0.16866596],
#        [-0.74914662,  0.25714638,  0.00272329, ..., -0.94480241,
#         -0.78772714, -0.64029575]])

# %%
Class_df.columns
# Out:
# Index(['capacity_mw', 'longitude', 'primary_fuel', 'commissioning_year',
#        'geolocation_source', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018'],
#       dtype='object')

# %%
Columnsname=['capacity_mw', 'longitude', 'commissioning_year',
       'geolocation_source', 'generation_gwh_2014', 'generation_gwh_2015',
       'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018']

# %%
new_x=pd.DataFrame(data=x,columns=Columnsname)

plt.figure(figsize=(20,25),facecolor='white')

plotn=1

for col in new_x:
    if plotn<=10:
        plt.subplot(7,4,plotn)
        sns.distplot(new_x[col])
        plt.xlabel(col,fontsize=15)
        
    plotn+=1   
    
plt.show()

# %% [markdown]
# Above is the grapg after we treated skewness and it looks symentric now as we required for our model

# %%
# Scalling data is always best pratice hence applying standered scaler 

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=Columnsname)
x.head()
# Out:
#    capacity_mw  longitude  commissioning_year  geolocation_source  \
# 0    -1.670775  -0.919452            1.147105           -2.275247
# 1     0.212831  -0.499913            0.002723            0.404765
# 2    -0.283603  -2.362902            0.002723            0.404765
# 3     0.385765   2.428670            0.318968            0.404765
# 4     1.755426   1.256600            1.683296            0.404765
#
#    generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0            -0.897785            -0.889530            -0.944802
# 1             0.412827             0.228256             0.399367
# 2            -0.181427             0.052900             0.118893
# 3             0.697166             0.898668             0.922871
# 4             1.393397             1.660129             1.631917
#
#    generation_gwh_2017  generation_gwh_2018
# 0            -0.787727            -0.640296
# 1             0.237482             0.244587
# 2             0.181831             0.041255
# 3             0.749300             0.615276
# 4             1.649018             1.894674

# %%
# Basically we dont need to check VIF as there in high dimensional data but still lest have look once

import statsmodels.api as sm
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['Features'] = x.columns
vif['VIF values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif
# Out:
#               Features  VIF values
# 0          capacity_mw    3.792663
# 1            longitude    1.194033
# 2   commissioning_year    1.127648
# 3   geolocation_source    1.404831
# 4  generation_gwh_2014    4.394288
# 5  generation_gwh_2015    6.551332
# 6  generation_gwh_2016   11.882450
# 7  generation_gwh_2017    7.442539
# 8  generation_gwh_2018    6.418164

# %% [markdown]
# Looking at above values its ok if we not treat VIF as we already have less variables

# %%
# let us check whether our label is equaly ditributed
y.value_counts()
# Out:
# 1    230
# 3    220
# 7    123
# 6    121
# 2     64
# 0     45
# 5     20
# 4      8
# Name: primary_fuel, dtype: int64

# %% [markdown]
# We can see that our labels are not equally distributted Hence we need to apply oversampling using SMOT

# %% [markdown]
# # SMOT

# %%
from imblearn.over_sampling import SMOTE
SM = SMOTE()
x, y = SM.fit_resample(x,y)
y.value_counts()
# Out:
# 7    230
# 6    230
# 5    230
# 4    230
# 3    230
# 2    230
# 1    230
# 0    230
# Name: primary_fuel, dtype: int64

# %% [markdown]
# Now our labels are equal and we can train models

# %%
# Both X and Y are equal
print(x.shape)
print(y.shape)
# Out:
# (1840, 9)
# (1840,)

# %% [markdown]
# # Now we can find best random state

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score
from sklearn.metrics import classification_report
from sklearn.metrics import plot_roc_curve
maxAcc = 0
maxRS = 0

for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20, random_state=i)
    modRF = RandomForestClassifier()
    modRF.fit(x_train,y_train)
    pred = modRF.predict(x_test)
    acc = accuracy_score(y_test,pred)
    if acc>maxAcc:
        maxAcc = acc
        maxRs=i
print(f"Best Accuracy is: {maxAcc} on Random State: {maxRs}")
# Out:
# Best Accuracy is: 0.9130434782608695 on Random State: 44

# %% [markdown]
# We found best random state as 44 which is giving us 91% accuracy

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier, BaggingClassifier

# %%
LOGR = LogisticRegression(solver = 'liblinear')
RFC = RandomForestClassifier()
DTC = DecisionTreeClassifier()
SV = SVC()
KNN = KNeighborsClassifier()
Gbc=GradientBoostingClassifier()
BG=BaggingClassifier()

model=[LOGR,RFC,DTC,SV,KNN,Gbc,BG]


for i in model:
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20, random_state=44)
    i.fit(x_train,y_train)
    predi=i.predict(x_test)
    print('performance matrix of',i,'is:')
    print("Confusion matrix :",confusion_matrix(y_test,predi))
    print("Classification report :", classification_report(y_test,predi,))
    print("Accuracy score :", accuracy_score(y_test,predi))
    print("*****************************************************************")
# Out:
# performance matrix of LogisticRegression(solver='liblinear') is:
# Confusion matrix : [[45  0  0  0  0  0  0  4]
#  [ 2 21  5 11  8  1  0  2]
#  [ 2 11 15  5  7  8  0  6]
#  [ 2  7  1 23  4  1  0  6]
#  [ 0  1  0  1 35  2  0  0]
#  [ 6  0  0  1  0 21  0 10]
#  [ 1  1  0  0  0  0 48  0]
#  [13  0  1  3  0  0  0 27]]
# Classification report :               precision    recall  f1-score   support
#
#            0       0.63      0.92      0.75        49
#            1       0.51      0.42      0.46        50
#            2       0.68      0.28      0.39        54
#            3       0.52      0.52      0.52        44
#            4       0.65      0.90      0.75        39
#            5       0.64      0.55      0.59        38
#            6       1.00      0.96      0.98        50
#            7       0.49      0.61      0.55        44
#
#     accuracy                           0.64       368
#    macro avg       0.64      0.65      0.62       368
# weighted avg       0.65      0.64      0.62       368
#
# Accuracy score : 0.6385869565217391
# *****************************************************************
# performance matrix of RandomForestClassifier() is:
# Confusion matrix : [[46  1  0  1  0  0  0  1]
#  [ 2 37  3  5  2  0  0  1]
#  [ 1  2 48  1  0  1  0  1]
#  [ 0  2  2 36  2  0  0  2]
#  [ 0  0  0  0 39  0  0  0]
#  [ 0  0  0  0  0 38  0  0]
#  [ 0  0  0  0  0  0 50  0]
#  [ 3  1  0  1  0  0  0 39]]
# Classification report :               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91        49
#            1       0.86      0.74      0.80        50
#            2       0.91      0.89      0.90        54
#            3       0.82      0.82      0.82        44
#            4       0.91      1.00      0.95        39
#            5       0.97      1.00      0.99        38
#            6       1.00      1.00      1.00        50
#            7       0.89      0.89      0.89        44
#
#     accuracy                           0.90       368
#    macro avg       0.90      0.91      0.91       368
# weighted avg       0.90      0.90      0.90       368
#
# Accuracy score : 0.904891304347826
# *****************************************************************
# performance matrix of DecisionTreeClassifier() is:
# Confusion matrix : [[45  1  0  1  0  0  0  2]
#  [ 0 28  6  8  4  0  0  4]
#  [ 3  3 41  5  1  1  0  0]
#  [ 0  3  5 35  1  0  0  0]
#  [ 0  4  0  0 35  0  0  0]
#  [ 0  0  0  1  0 34  0  3]
#  [ 0  0  0  1  0  0 49  0]
#  [ 3  2  1  1  0  0  0 37]]
# Classification report :               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90        49
#            1       0.68      0.56      0.62        50
#            2       0.77      0.76      0.77        54
#            3       0.67      0.80      0.73        44
#            4       0.85      0.90      0.88        39
#            5       0.97      0.89      0.93        38
#            6       1.00      0.98      0.99        50
#            7       0.80      0.84      0.82        44
#
#     accuracy                           0.83       368
#    macro avg       0.83      0.83      0.83       368
# weighted avg       0.83      0.83      0.82       368
#
# Accuracy score : 0.8260869565217391
# *****************************************************************
# performance matrix of SVC() is:
# Confusion matrix : [[49  0  0  0  0  0  0  0]
#  [ 4 20  9  3 11  0  0  3]
#  [ 4  4 37  2  1  2  0  4]
#  [ 1  3  7 27  1  2  0  3]
#  [ 0  0  0  0 39  0  0  0]
#  [ 3  0  0  0  0 26  0  9]
#  [ 0  1  0  0  0  0 49  0]
#  [16  0  0  0  0  1  0 27]]
# Classification report :               precision    recall  f1-score   support
#
#            0       0.64      1.00      0.78        49
#            1       0.71      0.40      0.51        50
#            2       0.70      0.69      0.69        54
#            3       0.84      0.61      0.71        44
#            4       0.75      1.00      0.86        39
#            5       0.84      0.68      0.75        38
#            6       1.00      0.98      0.99        50
#            7       0.59      0.61      0.60        44
#
#     accuracy                           0.74       368
#    macro avg       0.76      0.75      0.74       368
# weighted avg       0.76      0.74      0.73       368
#
# Accuracy score : 0.7445652173913043
# *****************************************************************
# performance matrix of KNeighborsClassifier() is:
# Confusion matrix : [[48  0  0  0  0  0  0  1]
#  [ 3 24 10  4  7  0  0  2]
#  [ 1  4 43  0  1  5  0  0]
#  [ 0  3  2 32  3  1  0  3]
#  [ 0  0  0  0 39  0  0  0]
#  [ 0  0  0  0  0 37  0  1]
#  [ 0  0  0  0  0  0 50  0]
#  [ 6  2  1  0  0  0  0 35]]
# Classification report :               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90        49
#            1       0.73      0.48      0.58        50
#            2       0.77      0.80      0.78        54
#            3       0.89      0.73      0.80        44
#            4       0.78      1.00      0.88        39
#            5       0.86      0.97      0.91        38
#            6       1.00      1.00      1.00        50
#            7       0.83      0.80      0.81        44
#
#     accuracy                           0.84       368
#    macro avg       0.84      0.84      0.83       368
# weighted avg       0.83      0.84      0.83       368
#
# Accuracy score : 0.8369565217391305
# *****************************************************************
# performance matrix of GradientBoostingClassifier() is:
# Confusion matrix : [[46  0  0  0  0  0  0  3]
#  [ 2 31  6  4  3  0  0  4]
#  [ 0  4 43  2  1  1  0  3]
#  [ 0  1  1 41  1  0  0  0]
#  [ 0  0  0  0 39  0  0  0]
#  [ 0  1  0  0  0 35  0  2]
#  [ 0  0  0  0  0  0 50  0]
#  [ 4  1  0  0  0  0  0 39]]
# Classification report :               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91        49
#            1       0.82      0.62      0.70        50
#            2       0.86      0.80      0.83        54
#            3       0.87      0.93      0.90        44
#            4       0.89      1.00      0.94        39
#            5       0.97      0.92      0.95        38
#            6       1.00      1.00      1.00        50
#            7       0.76      0.89      0.82        44
#
#     accuracy                           0.88       368
#    macro avg       0.88      0.89      0.88       368
# weighted avg       0.88      0.88      0.88       368
#
# Accuracy score : 0.8804347826086957
# *****************************************************************
# performance matrix of BaggingClassifier() is:
# Confusion matrix : [[46  1  0  1  0  0  0  1]
#  [ 1 34  3  6  3  0  0  3]
#  [ 1  6 46  0  0  0  0  1]
#  [ 0  3  5 34  1  0  0  1]
#  [ 0  0  0  0 39  0  0  0]
#  [ 0  0  0  0  0 36  0  2]
#  [ 0  0  0  0  0  0 50  0]
#  [ 2  2  0  1  0  0  0 39]]
# Classification report :               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93        49
#            1       0.74      0.68      0.71        50
#            2       0.85      0.85      0.85        54
#            3       0.81      0.77      0.79        44
#            4       0.91      1.00      0.95        39
#            5       1.00      0.95      0.97        38
#            6       1.00      1.00      1.00        50
#            7       0.83      0.89      0.86        44
#
#     accuracy                           0.88       368
#    macro avg       0.88      0.88      0.88       368
# weighted avg       0.88      0.88      0.88       368
#
# Accuracy score : 0.8804347826086957
# *****************************************************************

# %%
from sklearn.model_selection import cross_val_score
j=[LOGR,RFC,DTC,SV,KNN,Gbc,BG]
for n in j:
    print('Cross_Validation_score of',n,'is')
    score=cross_val_score(n,x,y,cv=5)
    print(score)
    print(score.mean())
    print(score.std())
    print('\n')
# Out:
# Cross_Validation_score of LogisticRegression(solver='liblinear') is
# [0.61413043 0.61413043 0.60326087 0.61413043 0.57065217]
# 0.6032608695652173
# 0.01683905802698876
#
#
# Cross_Validation_score of RandomForestClassifier() is
# [0.83695652 0.88586957 0.88586957 0.85326087 0.86684783]
# 0.8657608695652174
# 0.018951734537133367
#
#
# Cross_Validation_score of DecisionTreeClassifier() is
# [0.80706522 0.8125     0.85326087 0.84782609 0.80163043]
# 0.8244565217391303
# 0.021643812773630314
#
#
# Cross_Validation_score of SVC() is
# [0.72826087 0.73641304 0.72282609 0.70923913 0.7173913 ]
# 0.7228260869565217
# 0.009255101285829575
#
#
# Cross_Validation_score of KNeighborsClassifier() is
# [0.80978261 0.81521739 0.83967391 0.79619565 0.83423913]
# 0.8190217391304347
# 0.015993411923437117
#
#
# Cross_Validation_score of GradientBoostingClassifier() is
# [0.82880435 0.87771739 0.88586957 0.85869565 0.86684783]
# 0.8635869565217391
# 0.019700618435208556
#
#
# Cross_Validation_score of BaggingClassifier() is
# [0.82608696 0.86684783 0.86413043 0.8423913  0.8423913 ]
# 0.8483695652173914
# 0.015217391304347825

# %% [markdown]
# We can see that Decision tree accuracy is 82 and mean of cross validation is also 82 which is Good sign of model and we will hypertune parameter of this model

# %%
from sklearn.model_selection import GridSearchCV



parameters={"random_state":[44],"criterion": ['gini', 'entropy'],"max_depth":[2,4,6,8,10,12],"min_samples_leaf":[2,3,4,5,6]}

GVC=GridSearchCV(DecisionTreeClassifier(),parameters,cv=5)

# %%
GVC.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 6, 8, 10, 12],
#                          'min_samples_leaf': [2, 3, 4, 5, 6],
#                          'random_state': [44]})

# %%
GVC.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 12,
#  'min_samples_leaf': 2,
#  'random_state': 44}

# %%
#initialising GradientBoost with best parameter
Fuel_Model=DecisionTreeClassifier(criterion= 'gini',max_depth= 12,min_samples_leaf= 2,random_state=44)

# %%
Fuel_Model.fit(x_train, y_train)
pred = Fuel_Model.predict(x_test)
acc=accuracy_score(y_test,DTC.predict(x_test))
print("Accuracy Score",acc*100)
# Out:
# Accuracy Score 82.6086956521739

# %% [markdown]
# We are still ata 82 so we can save this model

# %% [markdown]
# # saving the model

# %%
# Saving the model using .pkl

import joblib
joblib.dump(Fuel_Model,"Global_Power_Fuel.pkl")
# Out:
# ['Global_Power_Fuel.pkl']

# %% [markdown]
# # Loading model to use

# %%
# Loading the saved model
model=joblib.load("Global_Power_Fuel.pkl")

#Prediction
prediction = model.predict(x_test)
prediction
# Out:
# array([0, 2, 7, 6, 7, 3, 6, 6, 2, 5, 7, 0, 1, 2, 2, 0, 2, 0, 2, 7, 6, 2,
#        7, 7, 6, 3, 6, 0, 5, 0, 5, 7, 3, 6, 2, 0, 2, 3, 1, 6, 4, 6, 0, 3,
#        7, 1, 0, 4, 1, 2, 3, 2, 2, 2, 5, 1, 6, 4, 4, 5, 5, 2, 6, 7, 6, 4,
#        1, 7, 2, 7, 7, 5, 5, 2, 3, 4, 2, 0, 0, 4, 4, 3, 1, 0, 5, 4, 0, 0,
#        4, 6, 1, 0, 0, 3, 2, 3, 3, 4, 0, 0, 2, 0, 7, 5, 2, 0, 4, 4, 5, 4,
#        3, 7, 6, 6, 5, 7, 7, 4, 1, 0, 6, 4, 6, 0, 3, 7, 1, 2, 5, 3, 5, 1,
#        3, 0, 6, 2, 5, 7, 4, 7, 5, 6, 4, 5, 0, 2, 3, 7, 6, 4, 7, 7, 3, 2,
#        2, 2, 5, 1, 5, 2, 3, 6, 3, 4, 0, 3, 6, 0, 1, 0, 1, 1, 2, 0, 5, 6,
#        2, 3, 6, 3, 6, 5, 1, 6, 5, 2, 4, 1, 1, 0, 7, 2, 2, 1, 5, 3, 3, 2,
#        3, 7, 7, 4, 2, 6, 1, 3, 5, 7, 7, 4, 1, 4, 3, 1, 7, 0, 3, 1, 3, 1,
#        2, 1, 6, 0, 2, 2, 3, 2, 3, 0, 6, 4, 4, 6, 1, 3, 3, 3, 6, 0, 0, 4,
#        2, 0, 7, 3, 2, 4, 4, 0, 2, 7, 0, 4, 6, 7, 0, 4, 7, 0, 1, 1, 2, 7,
#        0, 6, 2, 6, 4, 0, 0, 5, 4, 1, 5, 7, 0, 6, 0, 6, 5, 0, 1, 1, 6, 3,
#        1, 0, 6, 0, 1, 6, 4, 0, 0, 6, 2, 3, 3, 6, 2, 1, 1, 4, 6, 6, 2, 2,
#        7, 6, 4, 0, 2, 4, 6, 2, 4, 0, 5, 1, 5, 0, 5, 1, 4, 1, 2, 3, 2, 2,
#        2, 0, 4, 1, 0, 5, 5, 1, 1, 1, 2, 3, 6, 1, 7, 7, 6, 3, 0, 2, 0, 3,
#        3, 6, 3, 5, 2, 7, 7, 3, 4, 2, 1, 1, 0, 1, 3, 5])

# %% [markdown]
# # ROC Curve

# %%
tpr,fpr,thresholds = roc_curve(y_test,prediction,pos_label=True)
plt.plot(fpr,tpr,label = 'DecisionTreeClassifier')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('DecisionTreeClassifier')
plt.show()

# %% [markdown]
# Not A very perfect but quite ok curve

# %%
a=np.array(y_test)
result=pd.DataFrame({"Original":a,"Predicted":prediction})
result
# Out:
#      Original  Predicted
# 0           0          0
# 1           2          2
# 2           7          7
# 3           6          6
# 4           7          7
# ..        ...        ...
# 363         1          1
# 364         0          0
# 365         1          1
# 366         3          3
# 367         5          5
#
# [368 rows x 2 columns]

# %% [markdown]
# # So we can see above almost every value is matching well whatever is visible.

# %% [markdown]
# # Thank You
